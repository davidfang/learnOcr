# %% [markdown]
# #### 第二个测试
#
# 包导入

# %%
from PIL import Image
import cv2
from matplotlib import pyplot as plt
import numpy as np

import pytesseract

# 如果在 Windows 上，需要明确设置 tesseract_cmd 路径
pytesseract.pytesseract.tesseract_cmd = r'D:\Program Files\Tesseract-OCR\tesseract.exe'

# 如果在其他系统上，确保 tesseract 已正确安装并在系统路径中

# %%
# 加载灰度图
img = cv2.imread('G:/workSpace/python/MyOCR/images/1.jpg',cv2.IMREAD_GRAYSCALE)
# 将图像从 BGR 转换为 RGB
image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 显示原始图像
plt.figure(figsize=(10, 5))
# plt.subplot(1, 3, 1)
plt.imshow(image_rgb)
plt.title('Original Image')
# plt.axis('off')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
# 将图像转换为灰度图像
gray_image = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2GRAY)

# 显示灰度图像
# plt.subplot(1, 3, 2)
plt.imshow(gray_image, cmap='gray')
plt.title('Gray Image')
# plt.axis('off')
# Out:
# Text(0.5, 1.0, 'Gray Image')

# %%
# 二值化图像
_, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)

# 显示二值化图像
# plt.subplot(1, 3, 3)
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image')
# plt.axis('off')
# Out:
# Text(0.5, 1.0, 'Binary Image')

# %%
img = Image.open('G:/workSpace/python/MyOCR/images/1.jpg')

# 识别文字，并指定语言
string = pytesseract.image_to_string(img, lang='chi_sim')
print(string)
# Out:
# 00050123
#
# 怡 吊
# 人 一

# %%
import easyocr
print(easyocr.__version__)
# Out:
# 1.7.1

# %%
reader2 = easyocr.Reader(['en']) 
result = reader2.readtext('G:/workSpace/python/MyOCR/images/1.jpg')
print(result)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 reader2 = easyocr.Reader(['en'])
#       2 result = reader2.readtext('G:/workSpace/python/MyOCR/images/1.jpg')
#       3 print(result)
#
# File d:\ProgramData\anaconda3\envs\tensorflow\lib\site-packages\easyocr\easyocr.py:92, in Reader.__init__(self, lang_list, gpu, model_storage_directory, user_network_directory, detect_network, recog_network, download_enabled, detector, recognizer, verbose, quantize, cudnn_benchmark)
#      90 self.cudnn_benchmark=cudnn_benchmark
#      91 if detector:
# ---> 92     detector_path = self.getDetectorPath(detect_network)
#      94 # recognition model
#      95 separator_list = {}
#
# ...
