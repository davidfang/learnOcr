# %% [markdown]
# ##### [02: 基本元素 - 图片](https://codec.wang/docs/opencv/start/basic-element-image)

# %%
import pytesseract
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# 加载灰度图
img = cv2.imread('./images/lena.png', 0)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
#显示灰度图
plt.imshow(img,cmap='gray')

# %%
# 正常加载图
img2 = cv2.imread('./images/lena.png')

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
print(img2.shape)
# Out:
# (512, 512, 3)

# %%
#另一种显示图方法
plt.imshow(img2[:,:,::-1])
