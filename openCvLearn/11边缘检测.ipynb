# %% [markdown]
# ##### [11: 边缘检测](https://codec.wang/docs/opencv/basic/edge-detection)

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.sans-serif'] = ['WenQuanYi Zen Hei']  # 使用文泉驿字体
plt.rcParams['axes.unicode_minus'] = False  # 解决坐标轴负号显示问题

# %%
img = cv2.imread('images/handwriting.jpg',0)
edges = cv2.Canny(img,30,70) # canny 边缘检测

plt.figure(figsize=(12,8))
plt.subplot(131),plt.imshow(cv2.cvtColor(img,cv2.COLOR_GRAY2RGB))
plt.subplot(132),plt.imshow(cv2.cvtColor(edges,cv2.COLOR_GRAY2RGB))
plt.subplot(133),plt.imshow(edges)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7fa8c4fab4a0>)

# %% [markdown]
# ###### 先阈值分割后检测
# 其实很多情况下，阈值分割后再检测边缘，效果会更好：

# %%
_, thresh = cv2.threshold(img,0,255,cv2.THRESH_BINARY + cv2.THRESH_OTSU)
edges = cv2.Canny(thresh,30,70)

plt.figure(figsize=(12,8))
plt.subplot(131),plt.imshow(cv2.cvtColor(img,cv2.COLOR_GRAY2RGB))
plt.subplot(132),plt.imshow(cv2.cvtColor(thresh,cv2.COLOR_GRAY2RGB))
plt.subplot(133),plt.imshow(cv2.cvtColor(edges,cv2.COLOR_GRAY2RGB))
# plt.subplot(133),plt.imshow(edges)
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7fa8c4e0f9e0>)

# %%
# 寻找二值化图中的轮廓
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print(len(contours))  # 结果应该为 2
# Out:
# 3
